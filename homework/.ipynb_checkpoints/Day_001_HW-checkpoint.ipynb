# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# ## 作業1:
#
#
# 我找的資料:Titanic: [鐵達尼號乘客資料與存亡](https://www.kaggle.com/c/titanic/data)
# * 1.因為是有關鐵達尼號沉沒時死亡和存亡的乘客名單和身分以及各種資料，可用來分析存活乘客都有什麼特性，可當作船難事故存活機率的探討
# * 2.kaggle官方
# * 3.csv檔裡面包含乘客的編號和是否存活，以及Pclass	Name	Sex	Age	SibSp	Parch	Ticket	Fare	Cabin	Embarked，打開是excel檔，是結構化的表格
# * 4.what sorts of people were likely to survive?我假設老弱婦孺最容易存活，因為他們能優先搭救生艇，所以我就看性別是女性及年齡偏小或偏大的人是否存活比例最高，所以可以用MAE來計算

# %% [markdown]
# ## 作業2:
# * 1.車資越低，乘客越多，平均每台車每日接客數量越高，業績越好
# * 2.網路、顧客問卷調查、計程車公會資料、uber資料
# * 3.結構化：數值, 表格和非結構化的影音(顧客訪談)新聞(文字)
# * 4.從車資與乘客數量或搭乘意願的比較來驗證

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum(abs(y - yp)) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(pow((y - yp),2)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 13.939
# The Mean absolute error is 301.686
